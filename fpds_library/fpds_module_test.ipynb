# %%
# https://pypi.org/project/fpds/

from fpds import fpdsRequest
import json

# %%
request = fpdsRequest(
    LAST_MOD_DATE="[2022/01/01, 2022/01/02]",
    AGENCY_CODE="7523"
)

# %%
# Records saved as a python list
records = request()

# or equivalently, explicity call the `parse_content` method
records_parsed = request.parse_content()
# Out:
# 100%|██████████| 1/1 [00:01<00:00,  1.26s/it]
# 100%|██████████| 2/2 [00:02<00:00,  1.23s/it]

# %%
print(records)
print('--------------------------------')
print(records_parsed)

print(json.dumps(records_parsed, indent = 4))
# Out:
# [{'title': 'DEFINITIVE CONTRACT 75D30118C03504 (P00005) awarded to MUSCULAR DYSTROPHY ASSOCIATION, INC., was modified for the amount of $0', 'contract_type': 'AWARD', 'link__rel': 'alternate', 'link__type': 'text/html', 'link__href': 'https://www.fpds.gov/ezsearch/search.do?s=FPDS&indexName=awardfull&templateName=1.5.3&q=75D30118C03504+7523+', 'modified': '2022-01-01 16:13:11', 'content': '\n      ', 'content__type': 'application/xml', 'award': '\n        ', 'award__version': '1.5', 'awardID': '\n          ', 'awardID__awardContractID': '\n            ', 'awardID__awardContractID__agencyID': '7523', 'awardID__awardContractID__agencyID__name': 'CENTERS FOR DISEASE CONTROL AND PREVENTION', 'awardID__awardContractID__PIID': '75D30118C03504', 'awardID__awardContractID__modNumber': 'P00005', 'awardID__awardContractID__transactionNumber': '0', 'relevantContractDates': '\n          ', 'relevantContractDates__signedDate': '2022-01-01 00:00:00', 'relevantContractDates__effectiveDate': '2018-09-24 00:00:00', 'relevantContractDates__currentCompletionDate': '2022-09-23 00:00:00', 'relevantContractDates__ultimateCompletionDate': '2023-09-23 00:00:00', 'dollarValues': '\n          ', 'dollarValues__obligatedAmount': '0.00', 'dollarValues__baseAndExercisedOptionsValue': '0.00', 'dollarValues__baseAndAllOptionsValue': '0.00', 'totalDollarValues': '\n          ', 'totalDollarValues__totalObligatedAmount': '1368451.00', 'totalDollarValues__totalBaseAndExercisedOptionsValue': '1368451.00', 'totalDollarValues__totalBaseAndAllOptionsValue': '1741710.00', 'purchaserInformation': '\n          ', 'purchaserInformation__contractingOfficeAgencyID': '7523', 'purchaserInformation__contractingOfficeAgencyID__name': 'CENTERS FOR DISEASE CONTROL AND PREVENTION', 'purchaserInformation__contractingOfficeAgencyID__departmentID': '7500', 'purchaserInformation__contractingOfficeAgencyID__departmentName': 'HEALTH AND HUMAN SERVICES, DEPARTMENT OF', 'purchaserInformation__contractingOfficeID': '75D301', 'purchaserInformation__contractingOfficeID__name': 'CDC OFFICE OF ACQUISITION SERVICES', 'purchaserInformation__contractingOfficeID__country': 'USA', 'purchaserInformation__fundingRequestingAgencyID': '7523', 'purchaserInformation__fundingRequestingAgencyID__name': 'CENTERS FOR DISEASE CONTROL AND PREVENTION', 'purchaserInformation__fundingRequestingAgencyID__departmentID': '7500', 'purchaserInformation__fundingRequestingAgencyID__departmentName': 'HEALTH AND HUMAN SERVICES, DEPARTMENT OF', 'purchaserInformation__fundingRequestingOfficeID': '75D301', 'purchaserInformation__fundingRequestingOfficeID__name': 'CDC OFFICE OF ACQUISITION SERVICES', 'purchaserInformation__foreignFunding': 'X', 'purchaserInformation__foreignFunding__description': 'NOT APPLICABLE', 'contractMarketingData': '\n          ', 'contractMarketingData__feePaidForUseOfService': '0.00', 'contractData': '\n          ', 'contractData__contractActionType': 'D', 'contractData__contractActionType__description': 'DEFINITIVE CONTRACT', 'contractData__typeOfContractPricing': 'J', 'contractData__typeOfContractPricing__description': 'FIRM FIXED PRICE', 'contractData__reasonForModification': 'M', 'contractData__reasonForModification__description': 'OTHER ADMINISTRATIVE ACTION', 'contractData__nationalInterestActionCode': 'NONE', 'contractData__nationalInterestActionCode__description': 'NONE', 'contractData__costOrPricingData': 'N', 'contractData__costOrPricingData__description': 'No', 'contractData__solicitationID': '2018N67818', 'contractData__costAccountingStandardsClause': 'N', 'contractData__costAccountingStandardsClause__description': 'NO - CAS WAIVER APPROVED', 'contractData__descriptionOfContractRequirement': 'ALS MDA NATIONAL ALS REGISTRY COMMUNICATIONS AND OUTREACH TECHNICAL SUPPORT', 'contractData__inherentlyGovernmentalFunction': 'CL        ', 'contractData__inherentlyGovernmentalFunction__description': 'CLOSELY ASSOCIATED', 'contractData__GFE-GFP': 'N', 'contractData__GFE-GFP__description': 'Trans ...
# --------------------------------
# [{'title': 'DEFINITIVE CONTRACT 75D30118C03504 (P00005) awarded to MUSCULAR DYSTROPHY ASSOCIATION, INC., was modified for the amount of $0', 'contract_type': 'AWARD', 'link__rel': 'alternate', 'link__type': 'text/html', 'link__href': 'https://www.fpds.gov/ezsearch/search.do?s=FPDS&indexName=awardfull&templateName=1.5.3&q=75D30118C03504+7523+', 'modified': '2022-01-01 16:13:11', 'content': '\n      ', 'content__type': 'application/xml', 'award': '\n        ', 'award__version': '1.5', 'awardID': '\n          ', 'awardID__awardContractID': '\n            ', 'awardID__awardContractID__agencyID': '7523', 'awardID__awardContractID__agencyID__name': 'CENTERS FOR DISEASE CONTROL AND PREVENTION', 'awardID__awardContractID__PIID': '75D30118C03504', 'awardID__awardContractID__modNumber': 'P00005', 'awardID__awardContractID__transactionNumber': '0', 'relevantContractDates': '\n          ', 'relevantContractDates__signedDate': '2022-01-01 00:00:00', 'relevantContractDates__effectiveDate': '2018-09-24 00:00:00', 'relevantContractDates__currentCompletionDate': '2022-09-23 00:00:00', 'relevantContractDates__ultimateCompletionDate': '2023-09-23 00:00:00', 'dollarValues': '\n          ', 'dollarValues__obligatedAmount': '0.00', 'dollarValues__baseAndExercisedOptionsValue': '0.00', 'dollarValues__baseAndAllOptionsValue': '0.00', 'totalDollarValues': '\n          ', 'totalDollarValues__totalObligatedAmount': '1368451.00', 'totalDollarValues__totalBaseAndExercisedOptionsValue': '1368451.00', 'totalDollarValues__totalBaseAndAllOptionsValue': '1741710.00', 'purchaserInformation': '\n          ', 'purchaserInformation__contractingOfficeAgencyID': '7523', 'purchaserInformation__contractingOfficeAgencyID__name': 'CENTERS FOR DISEASE CONTROL AND PREVENTION', 'purchaserInformation__contractingOfficeAgencyID__departmentID': '7500', 'purchaserInformation__contractingOfficeAgencyID__departmentName': 'HEALTH AND HUMAN SERVICES, DEPARTMENT OF', 'purchaserInformation__contractingOfficeID': '75D301', 'purchaserInformation__contractingOfficeID__name': 'CDC OFFICE OF ACQUISITION SERVICES', 'purchaserInformation__contractingOfficeID__country': 'USA', 'purchaserInformation__fundingRequestingAgencyID': '7523', 'purchaserInformation__fundingRequestingAgencyID__name': 'CENTERS FOR DISEASE CONTROL AND PREVENTION', 'purchaserInformation__fundingRequestingAgencyID__departmentID': '7500', 'purchaserInformation__fundingRequestingAgencyID__departmentName': 'HEALTH AND HUMAN SERVICES, DEPARTMENT OF', 'purchaserInformation__fundingRequestingOfficeID': '75D301', 'purchaserInformation__fundingRequestingOfficeID__name': 'CDC OFFICE OF ACQUISITION SERVICES', 'purchaserInformation__foreignFunding': 'X', 'purchaserInformation__foreignFunding__description': 'NOT APPLICABLE', 'contractMarketingData': '\n          ', 'contractMarketingData__feePaidForUseOfService': '0.00', 'contractData': '\n          ', 'contractData__contractActionType': 'D', 'contractData__contractActionType__description': 'DEFINITIVE CONTRACT', 'contractData__typeOfContractPricing': 'J', 'contractData__typeOfContractPricing__description': 'FIRM FIXED PRICE', 'contractData__reasonForModification': 'M', 'contractData__reasonForModification__description': 'OTHER ADMINISTRATIVE ACTION', 'contractData__nationalInterestActionCode': 'NONE', 'contractData__nationalInterestActionCode__description': 'NONE', 'contractData__costOrPricingData': 'N', 'contractData__costOrPricingData__description': 'No', 'contractData__solicitationID': '2018N67818', 'contractData__costAccountingStandardsClause': 'N', 'contractData__costAccountingStandardsClause__description': 'NO - CAS WAIVER APPROVED', 'contractData__descriptionOfContractRequirement': 'ALS MDA NATIONAL ALS REGISTRY COMMUNICATIONS AND OUTREACH TECHNICAL SUPPORT', 'contractData__inherentlyGovernmentalFunction': 'CL        ', 'contractData__inherentlyGovernmentalFunction__description': 'CLOSELY ASSOCIATED', 'contractData__GFE-GFP': 'N', 'contractData__GFE-GFP__description': 'Trans ...
# [
#     {
#         "title": "DEFINITIVE CONTRACT 75D30118C03504 (P00005) awarded to MUSCULAR DYSTROPHY ASSOCIATION, INC., was modified for the amount of $0",
#         "contract_type": "AWARD",
#         "link__rel": "alternate",
#         "link__type": "text/html",
#         "link__href": "https://www.fpds.gov/ezsearch/search.do?s=FPDS&indexName=awardfull&templateName=1.5.3&q=75D30118C03504+7523+",
#         "modified": "2022-01-01 16:13:11",
#         "content": "\n      ",
#         "content__type": "application/xml",
#         "award": "\n        ",
#         "award__version": "1.5",
#         "awardID": "\n          ",
#         "awardID__awardContractID": "\n            ",
#         "awardID__awardContractID__agencyID": "7523",
#         "awardID__awardContractID__agencyID__name": "CENTERS FOR DISEASE CONTROL AND PREVENTION",
#         "awardID__awardContractID__PIID": "75D30118C03504",
#         "awardID__awardContractID__modNumber": "P00005",
#         "awardID__awardContractID__transactionNumber": "0",
#         "relevantContractDates": "\n          ",
#         "relevantContractDates__signedDate": "2022-01-01 00:00:00",
#         "relevantContractDates__effectiveDate": "2018-09-24 00:00:00",
#         "relevantContractDates__currentCompletionDate": "2022-09-23 00:00:00",
#         "relevantContractDates__ultimateCompletionDate": "2023-09-23 00:00:00",
#         "dollarValues": "\n          ",
#         "dollarValues__obligatedAmount": "0.00",
#         "dollarValues__baseAndExercisedOptionsValue": "0.00",
#         "dollarValues__baseAndAllOptionsValue": "0.00",
#         "totalDollarValues": "\n          ",
#         "totalDollarValues__totalObligatedAmount": "1368451.00",
#         "totalDollarValues__totalBaseAndExercisedOptionsValue": "1368451.00",
#         "totalDollarValues__totalBaseAndAllOptionsValue": "1741710.00",
#         "purchaserInformation": "\n          ",
#         "purchaserInformation__contractingOfficeAgencyID": "7523",
#         "purchaserInformation__contractingOfficeAgencyID__name": "CENTERS FOR DISEASE CONTROL AND PREVENTION",
#         "purchaserInformation__contractingOfficeAgencyID__departmentID": "7500",
#         "purchaserInformation__contractingOfficeAgencyID__departmentName": "HEALTH AND HUMAN SERVICES, DEPARTMENT OF",
#         "purchaserInformation__contractingOfficeID": "75D301",
#         "purchaserInformation__contractingOfficeID__name": "CDC OFFICE OF ACQUISITION SERVICES",
#         "purchaserInformation__contractingOfficeID__country": "USA",
#         "purchaserInformation__fundingRequestingAgencyID": "7523",
#         "purchaserInformation__fundingRequestingAgencyID__name": "CENTERS FOR DISEASE CONTROL AND PREVENTION",
#         "purchaserInformation__fundingRequestingAgencyID__departmentID": "7500",
#         "purchaserInformation__fundingRequestingAgencyID__departmentName": "HEALTH AND HUMAN SERVICES, DEPARTMENT OF",
#         "purchaserInformation__fundingRequestingOfficeID": "75D301",
#         "purchaserInformation__fundingRequestingOfficeID__name": "CDC OFFICE OF ACQUISITION SERVICES",
#         "purchaserInformation__foreignFunding": "X",
#         "purchaserInformation__foreignFunding__description": "NOT APPLICABLE",
#         "contractMarketingData": "\n          ",
#         "contractMarketingData__feePaidForUseOfService": "0.00",
#         "contractData": "\n          ",
#         "contractData__contractActionType": "D",
#         "contractData__contractActionType__description": "DEFINITIVE CONTRACT",
#         "contractData__typeOfContractPricing": "J",
#         "contractData__typeOfContractPricing__description": "FIRM FIXED PRICE",
#         "contractData__reasonForModification": "M",
#         "contractData__reasonForModification__description": "OTHER ADMINISTRATIVE ACTION",
#         "contractData__nationalInterestActionCode": "NONE",
#         "contractData__nationalInterestActionCode__description": "NONE",
#         "contractData__costOrPricingData": "N",
#         "contractData__costOrPricingData__description": "No",
#         "contractData__solicitationID": "2018N67818",
#         "contractData__costAccountingStandardsClause": "N",
#         "contractData__costAccountingStandardsClause__description": "NO - CAS WAIVER APPROVED",
#         "contractData__descriptionOfContractRequirement": "ALS MDA NATIONAL ALS REGISTRY COMMUNICATIONS AND OUTREACH TECHNICAL SUPPORT",
#         "contractData__inherentlyGovernmentalFunction": "CL        ",
#         "contractData__inherentlyGovernmentalFunction__description": "CLOSELY ASSOCIATED",
#         "contractData__GFE-GFP": "N",
#         "contractData__GFE-GFP__description": "Transaction does not use GFE/GFP",
#         "contractData__undefinitizedAction": "X",
#         "contractData__undefinitizedAction__description": "NO",
#         "contractData__consolidatedContract": "D",
#         "contractData__consolidatedContract__description": "NOT CONSOLIDATED",
#         "contractData__performanceBasedServiceContract": "N",
#         "contractData__performanceBasedServiceContract__description": "NO - SERVICE WHERE PBA IS NOT USED.",
#         "contractData__multiYearContract": "N",
#         "contractData__multiYearContract__description": "NO",
#         "contractData__contingencyHumanitarianPeacekeepingOperation": "X",
#         "contractData__contingencyHumanitarianPeacekeepingOperation__description": "NOT APPLICABLE",
#         "contractData__contractFinancing": "Z",
#         "contractData__contractFinancing__description": "NOT APPLICABLE",
#         "contractData__purchaseCardAsPaymentMethod": "N",
#         "contractData__purchaseCardAsPaymentMethod__description": "NO",
#         "contractData__numberOfActions": "1",
#         "legislativeMandates": "\n          ",
#         "legislativeMandates__ClingerCohenAct": "N",
#         "legislativeMandates__ClingerCohenAct__description": "NO",
#         "legislativeMandates__materialsSuppliesArticlesEquipment": "N",
#         "legislativeMandates__materialsSuppliesArticlesEquipment__description": "NO",
#         "legislativeMandates__laborStandards": "N",
#         "legislativeMandates__laborStandards__description": "NO",
#         "legislativeMandates__constructionWageRateRequirements": "N",
#         "legislativeMandates__constructionWageRateRequirements__description": "NO",
#         "legislativeMandates__listOfAdditionalReportingValues": "\n            ",
#         "legislativeMandates__listOfAdditionalReportingValues__additionalReportingValue": "NONE",
#         "legislativeMandates__listOfAdditionalReportingValues__additionalReportingValue__description": "NONE OF THE ABOVE",
#         "legislativeMandates__interagencyContractingAuthority": "B",
#         "legislativeMandates__interagencyContractingAuthority__description": "OTHER STATUTORY AUTHORITY",
#         "legislativeMandates__otherStatutoryAuthority": "FALSE",
#         "productOrServiceInformation": "\n          ",
#         "productOrServiceInformation__productOrServiceCode": "R499",
#         "productOrServiceInformation__productOrServiceCode__description": "SUPPORT- PROFESSIONAL: OTHER",
#         "productOrServiceInformation__productOrServiceCode__productOrServiceType": "SERVICE",
#         "productOrServiceInformation__contractBundling": "H",
#         "productOrServiceInformation__contractBundling__description": "NOT BUNDLED",
#         "productOrServiceInformation__principalNAICSCode": "541990",
#         "productOrServiceInformation__principalNAICSCode__description": "ALL OTHER PROFESSIONAL, SCIENTIFIC, AND TECHNICAL SERVICES",
#         "productOrServiceInformation__recoveredMaterialClauses": "C",
#         "productOrServiceInformation__recoveredMaterialClauses__description": "NO CLAUSES INCLUDED AND NO SUSTAINABILITY INCLUDED",
#         "productOrServiceInformation__manufacturingOrganizationType": "A",
#         "productOrServiceInformation__manufacturingOrganizationType__description": "U.S. OWNED BUSINESS",
#         "productOrServiceInformation__useOfEPADesignatedProducts": "E",
#         "productOrServiceInformation__useOfEPADesignatedProducts__description": "NOT REQUIRED",
#         "productOrServiceInformation__countryOfOrigin": "USA",
#         "productOrServiceInformation__countryOfOrigin__name": "UNITED STATES",
#         "productOrServiceInformation__placeOfManufacture": "C",
#         "productOrServiceInformation__placeOfManufacture__description": "NOT A MANUFACTURED END PRODUCT",
#         "vendor": "\n          ",
#         "vendor__vendorHeader": "\n            ",
#         "vendor__vendorHeader__vendorName": "MUSCULAR DYSTROPHY ASSOCIATION, INC.",
#         "vendor__vendorHeader__vendorAlternateName": "MDA",
#         "vendor__vendorHeader__vendorLegalOrganizationName": "MUSCULAR DYSTROPHY ASSOCIATION, INC.",
#         "vendor__vendorSiteDetails": "\n            ",
#         "vendor__vendorSiteDetails__vendorSocioEconomicIndicators": "\n              ",
#         "vendor__vendorSiteDetails__vendorSocioEconomicIndicators__isAlaskanNativeOwnedCorporationOrFirm": "false",
#         "vendor__vendorSiteDetails__vendorSocioEconomicIndicators__isAmericanIndianOwned": "false",
#         "vendor__vendorSiteDetails__vendorSocioEconomicIndicators__isIndianTribe": "false",
#         "vendor__vendorSiteDetails__vendorSocioEconomicIndicators__isNativeHawaiianOwnedOrganizationOrFirm": "false",
#         "vendor__vendorSiteDetails__vendorSocioEconomicIndicators__isTriballyOwnedFirm": "false",
#         "vendor__vendorSiteDetails__vendorSocioEconomicIndicators__isSmallBusiness": "false",
#         "vendor__vendorSiteDetails__vendorSocioEconomicIndicators__isVeteranOwned": "false",
#         "vendor__vendorSiteDetails__vendorSocioEconomicIndicators__isServiceRelatedDisabledVeteranOwnedBusiness": "false",
#         "vendor__vendorSiteDetails__vendorSocioEconomicIndicators__isWomenOwned": "false",
#         "vendor__vendorSiteDetails__vendorSocioEconomicIndicators__minorityOwned": "\n                ",
#         "vendor__vendorSiteDetails__vendorSocioEconomicIndicators__minorityOwned__isMinorityOwned": "false",
#         "vendor__vendorSiteDetails__vendorSocioEconomicIndicators__minorityOwned__isSubContinentAsianAmericanOwnedBusiness": "false",
#         "vendor__vendorSiteDetails__vendorSocioEconomicIndicators__minorityOwned__isAsianPacificAmericanOwnedBusiness": "false",
#         "vendor__vendorSiteDetails__vendorSocioEconomicIndicators__minorityOwned__isBlackAmericanOwnedBusiness": "false",
#         "vendor__vendorSiteDetails__vendorSocioEconomicIndicators__minorityOwned__isHispanicAmericanOwnedBusiness": "false",
#         "vendor__vendorSiteDetails__vendorSocioEconomicIndicators__minorityOwned__isNativeAmericanOwnedBusiness": "false",
#         "vendor__vendorSiteDetails__vendorSocioEconomicIndicators__minorityOwned__isOtherMinorityOwned": "false",
#         "vendor__vendorSiteDetails__vendorSocioEconomicIndicators__isVerySmallBusiness": "false",
#         "vendor__vendorSiteDetails__vendorSocioEconomicIndicators__isWomenOwnedSmallBusiness": "false",
#         "vendor__vendorSiteDetails__vendorSocioEconomicIndicators__isEconomicallyDisadvantagedWomenOwnedSmallBusiness": "false",
#         "vendor__vendorSiteDetails__vendorSocioEconomicIndicators__isJointVentureWomenOwnedSmallBusiness": "false",
#         "vendor__vendorSiteDetails__vendorSocioEconomicIndicators__isJointVentureEconomicallyDisadvantagedWomenOwnedSmallBusiness": "false",
#         "vendor__vendorSiteDetails__vendorBusinessTypes": "\n              ",
#         "vendor__vendorSiteDetails__vendorBusinessTypes__isCommunityDevelopedCorporationOwnedFirm": "false",
#         "vendor__vendorSiteDetails__vendorBusinessTypes__isLaborSurplusAreaFirm": "false",
#         "vendor__vendorSiteDetails__vendorBusinessTypes__federalGovernment": "\n                ",
#         "vendor__vendorSiteDetails__vendorBusinessTypes__federalGovernment__isFederalGovernment": "false",
#         "vendor__vendorSiteDetails__vendorBusinessTypes__federalGovernment__isFederallyFundedResearchAndDevelopmentCorp": "false",
#         "vendor__vendorSiteDetails__vendorBusinessTypes__federalGovernment__isFederalGovernmentAgency": "false",
#         "vendor__vendorSiteDetails__vendorBusinessTypes__isStateGovernment": "false",
#         "vendor__vendorSiteDetails__vendorBusinessTypes__localGovernment": "\n                ",
#         "vendor__vendorSiteDetails__vendorBusinessTypes__localGovernment__isLocalGovernment": "false",
#         "vendor__vendorSiteDetails__vendorBusinessTypes__localGovernment__isCityLocalGovernment": "false",
#         "vendor__vendorSiteDetails__vendorBusinessTypes__localGovernment__isCountyLocalGovernment": "false",
#         "vendor__vendorSiteDetails__vendorBusinessTypes__localGovernment__isInterMunicipalLocalGovernment": "false",
#         "vendor__vendorSiteDetails__vendorBusinessTypes__localGovernment__isLocalGovernmentOwned": "false",
#         "vendor__vendorSiteDetails__vendorBusinessTypes__localGovernment__isMunicipalityLocalGovernment": "false",
#         "vendor__vendorSiteDetails__vendorBusinessTypes__localGovernment__isSchoolDistrictLocalGovernment": "false",
#         "vendor__vendorSiteDetails__vendorBusinessTypes__localGovernment__isTownshipLocalGovernment": "false",
#         "vendor__vendorSiteDetails__vendorBusinessTypes__isTribalGovernment": "false",
#         "vendor__vendorSiteDetails__vendorBusinessTypes__isForeignGovernment": "false",
#         "vendor__vendorSiteDetails__vendorBusinessTypes__businessOrOrganizationType": "\n                ",
#         "vendor__vendorSiteDetails__vendorBusinessTypes__businessOrOrganizationType__isCorporateEntityNotTaxExempt": "false",
#         "vendor__vendorSiteDetails__vendorBusinessTypes__businessOrOrganizationType__isCorporateEntityTaxExempt": "true",
#         "vendor__vendorSiteDetails__vendorBusinessTypes__businessOrOrganizationType__isPartnershipOrLimitedLiabilityPartnership": "false",
#         "vendor__vendorSiteDetails__vendorBusinessTypes__businessOrOrganizationType__isSolePropreitorship": "false",
#         "vendor__vendorSiteDetails__vendorBusinessTypes__businessOrOrganizationType__isSmallAgriculturalCooperative": "false",
#         "vendor__vendorSiteDetails__vendorBusinessTypes__businessOrOrganizationType__isInternationalOrganization": "false",
#         "vendor__vendorSiteDetails__vendorBusinessTypes__businessOrOrganizationType__isUSGovernmentEntity": "false",
#         "vendor__vendorSiteDetails__vendorLineOfBusiness": "\n              ",
#         "vendor__vendorSiteDetails__vendorLineOfBusiness__isCommunityDevelopmentCorporation": "false",
#         "vendor__vendorSiteDetails__vendorLineOfBusiness__isDomesticShelter": "false",
#         "vendor__vendorSiteDetails__vendorLineOfBusiness__isEducationalInstitution": "false",
#         "vendor__vendorSiteDetails__vendorLineOfBusiness__isFoundation": "false",
#         "vendor__vendorSiteDetails__vendorLineOfBusiness__isHospital": "false",
#         "vendor__vendorSiteDetails__vendorLineOfBusiness__isManufacturerOfGoods": "false",
#         "vendor__vendorSiteDetails__vendorLineOfBusiness__isVeterinaryHospital": "false",
#         "vendor__vendorSiteDetails__vendorLineOfBusiness__isHispanicServicingInstitution": "false",
#         "vendor__vendorSiteDetails__vendorRelationshipWithFederalGovernment": "\n              ",
#         "vendor__vendorSiteDetails__vendorRelationshipWithFederalGovernment__receivesContracts": "false",
#         "vendor__vendorSiteDetails__vendorRelationshipWithFederalGovernment__receivesGrants": "false",
#         "vendor__vendorSiteDetails__vendorRelationshipWithFederalGovernment__receivesContractsAndGrants": "true",
#         "vendor__vendorSiteDetails__typeOfGovernmentEntity": "\n              ",
#         "vendor__vendorSiteDetails__typeOfGovernmentEntity__isAirportAuthority": "false",
#         "vendor__vendorSiteDetails__typeOfGovernmentEntity__isCouncilOfGovernments": "false",
#         "vendor__vendorSiteDetails__typeOfGovernmentEntity__isHousingAuthoritiesPublicOrTribal": "false",
#         "vendor__vendorSiteDetails__typeOfGovernmentEntity__isInterstateEntity": "false",
#         "vendor__vendorSiteDetails__typeOfGovernmentEntity__isPlanningCommission": "false",
#         "vendor__vendorSiteDetails__typeOfGovernmentEntity__isPortAuthority": "false",
#         "vendor__vendorSiteDetails__typeOfGovernmentEntity__isTransitAuthority": "false",
#         "vendor__vendorSiteDetails__vendorOrganizationFactors": "\n              ",
#         "vendor__vendorSiteDetails__vendorOrganizationFactors__isSubchapterSCorporation": "false",
#         "vendor__vendorSiteDetails__vendorOrganizationFactors__isLimitedLiabilityCorporation": "false",
#         "vendor__vendorSiteDetails__vendorOrganizationFactors__isForeignOwnedAndLocated": "false",
#         "vendor__vendorSiteDetails__vendorOrganizationFactors__profitStructure": "\n                ",
#         "vendor__vendorSiteDetails__vendorOrganizationFactors__profitStructure__isForProfitOrganization": "false",
#         "vendor__vendorSiteDetails__vendorOrganizationFactors__profitStructure__isNonprofitOrganization": "true",
#         "vendor__vendorSiteDetails__vendorOrganizationFactors__profitStructure__isOtherNotForProfitOrganization": "false",
#         "vendor__vendorSiteDetails__vendorOrganizationFactors__isShelteredWorkshop": "false",
#         "vendor__vendorSiteDetails__vendorOrganizationFactors__stateOfIncorporation": "NY",
#         "vendor__vendorSiteDetails__vendorOrganizationFactors__stateOfIncorporation__name": "NEW YORK",
#         "vendor__vendorSiteDetails__vendorOrganizationFactors__countryOfIncorporation": "USA",
#         "vendor__vendorSiteDetails__vendorOrganizationFactors__countryOfIncorporation__name": "UNITED STATES",
#         "vendor__vendorSiteDetails__vendorOrganizationFactors__organizationalType": "CORPORATE TAX EXEMPT",
#         "vendor__vendorSiteDetails__typeOfEducationalEntity": "\n              ",
#         "vendor__vendorSiteDetails__typeOfEducationalEntity__is1862LandGrantCollege": "false",
#         "vendor__vendorSiteDetails__typeOfEducationalEntity__is1890LandGrantCollege": "false",
#         "vendor__vendorSiteDetails__typeOfEducationalEntity__is1994LandGrantCollege": "false",
#         "vendor__vendorSiteDetails__typeOfEducationalEntity__isHistoricallyBlackCollegeOrUniversity": "false",
#         "vendor__vendorSiteDetails__typeOfEducationalEntity__isMinorityInstitution": "false",
#         "vendor__vendorSiteDetails__typeOfEducationalEntity__isPrivateUniversityOrCollege": "false",
#         "vendor__vendorSiteDetails__typeOfEducationalEntity__isSchoolOfForestry": "false",
#         "vendor__vendorSiteDetails__typeOfEducationalEntity__isStateControlledInstitutionofHigherLearning": "false",
#         "vendor__vendorSiteDetails__typeOfEducationalEntity__isTribalCollege": "false",
#         "vendor__vendorSiteDetails__typeOfEducationalEntity__isVeterinaryCollege": "false",
#         "vendor__vendorSiteDetails__typeOfEducationalEntity__isAlaskanNativeServicingInstitution": "false",
#         "vendor__vendorSiteDetails__typeOfEducationalEntity__isNativeHawaiianServicingInstitution": "false",
#         "vendor__vendorSiteDetails__vendorCertifications": "\n              ",
#         "vendor__vendorSiteDetails__vendorCertifications__isDOTCertifiedDisadvantagedBusinessEnterprise": "false",
#         "vendor__vendorSiteDetails__vendorCertifications__isSelfCertifiedSmallDisadvantagedBusiness": "false",
#         "vendor__vendorSiteDetails__vendorCertifications__isSBACertifiedSmallDisadvantagedBusiness": "false",
#         "vendor__vendorSiteDetails__vendorCertifications__isSBACertified8AProgramParticipant": "false",
#         "vendor__vendorSiteDetails__vendorCertifications__isSelfCertifiedHUBZoneJointVenture": "false",
#         "vendor__vendorSiteDetails__vendorCertifications__isSBACertifiedHUBZone": "false",
#         "vendor__vendorSiteDetails__vendorCertifications__isSBACertified8AJointVenture": "false",
#         "vendor__vendorSiteDetails__vendorLocation": "\n              ",
#         "vendor__vendorSiteDetails__vendorLocation__streetAddress": "222 S RIVERSIDE PLZ STE 1500",
#         "vendor__vendorSiteDetails__vendorLocation__city": "CHICAGO",
#         "vendor__vendorSiteDetails__vendorLocation__state": "IL",
#         "vendor__vendorSiteDetails__vendorLocation__state__name": "ILLINOIS",
#         "vendor__vendorSiteDetails__vendorLocation__ZIPCode": "606066000",
#         "vendor__vendorSiteDetails__vendorLocation__ZIPCode__city": "CHICAGO",
#         "vendor__vendorSiteDetails__vendorLocation__countryCode": "USA",
#         "vendor__vendorSiteDetails__vendorLocation__countryCode__name": "UNITED STATES",
#         "vendor__vendorSiteDetails__vendorLocation__phoneNo": "3122605975",
#         "vendor__vendorSiteDetails__vendorLocation__congressionalDistrictCode": "07",
#         "vendor__vendorSiteDetails__vendorLocation__entityDataSource": "D&B",
#         "vendor__vendorSiteDetails__vendorAlternateSiteCode": "60606",
#         "vendor__vendorSiteDetails__entityIdentifiers": "\n              ",
#         "vendor__vendorSiteDetails__entityIdentifiers__vendorUEIInformation": "\n                ",
#         "vendor__vendorSiteDetails__entityIdentifiers__vendorUEIInformation__UEI": "MZL5EGRMMXY5",
#         "vendor__vendorSiteDetails__entityIdentifiers__vendorUEIInformation__UEILegalBusinessName": "MUSCULAR DYSTROPHY ASSOCIATION, INC.",
#         "vendor__vendorSiteDetails__entityIdentifiers__vendorUEIInformation__ultimateParentUEI": "MZL5EGRMMXY5",
#         "vendor__vendorSiteDetails__entityIdentifiers__vendorUEIInformation__ultimateParentUEIName": "MUSCULAR DYSTROPHY ASSOCIATION, INC.",
#         "vendor__vendorSiteDetails__entityIdentifiers__cageCode": "5EK24",
#         "vendor__vendorSiteDetails__ccrRegistrationDetails": "\n              ",
#         "vendor__vendorSiteDetails__ccrRegistrationDetails__registrationDate": "2009-04-14 00:00:00",
#         "vendor__vendorSiteDetails__ccrRegistrationDetails__renewalDate": "2019-09-18 00:00:00",
#         "vendor__contractingOfficerBusinessSizeDetermination": "O",
#         "vendor__contractingOfficerBusinessSizeDetermination__description": "OTHER THAN SMALL BUSINESS",
#         "placeOfPerformance": "\n          ",
#         "placeOfPerformance__principalPlaceOfPerformance": "\n            ",
#         "placeOfPerformance__principalPlaceOfPerformance__stateCode": "IL",
#         "placeOfPerformance__principalPlaceOfPerformance__stateCode__name": "ILLINOIS",
#         "placeOfPerformance__principalPlaceOfPerformance__countryCode": "USA",
#         "placeOfPerformance__principalPlaceOfPerformance__countryCode__name": "UNITED STATES",
#         "placeOfPerformance__placeOfPerformanceZIPCode": "606066000",
#         "placeOfPerformance__placeOfPerformanceZIPCode__county": "COOK",
#         "placeOfPerformance__placeOfPerformanceZIPCode__city": "CHICAGO",
#         "placeOfPerformance__placeOfPerformanceCongressionalDistrict": "07",
#         "competition": "\n          ",
#         "competition__extentCompeted": "C",
#         "competition__extentCompeted__description": "NOT COMPETED",
#         "competition__solicitationProcedures": "SSS",
#         "competition__solicitationProcedures__description": "ONLY ONE SOURCE",
#         "competition__typeOfSetAside": "NONE",
#         "competition__typeOfSetAside__description": "NO SET ASIDE USED.",
#         "competition__typeOfSetAsideSource": "F",
#         "competition__typeOfSetAsideSource__description": "This Action",
#         "competition__evaluatedPreference": "NONE",
#         "competition__evaluatedPreference__description": "NO PREFERENCE USED",
#         "competition__reasonNotCompeted": "ONE",
#         "competition__reasonNotCompeted__description": "ONLY ONE SOURCE-OTHER (FAR 6.302-1 OTHER)",
#         "competition__numberOfOffersReceived": "1",
#         "competition__numberOfOffersSource": "F",
#         "competition__numberOfOffersSource__description": "This Action",
#         "competition__commercialItemAcquisitionProcedures": "D",
#         "competition__commercialItemAcquisitionProcedures__description": "COMMERCIAL ITEM PROCEDURES NOT USED",
#         "competition__commercialItemTestProgram": "N",
#         "competition__commercialItemTestProgram__description": "NO",
#         "competition__A76Action": "N",
#         "competition__A76Action__description": "NO",
#         "competition__fedBizOpps": "Y",
#         "competition__fedBizOpps__description": "YES",
#         "competition__localAreaSetAside": "N",
#         "competition__localAreaSetAside__description": "NO",
#         "competition__priceEvaluationPercentDifference": "0.00",
#         "preferencePrograms": "\n          ",
#         "preferencePrograms__subcontractPlan": "F",
#         "preferencePrograms__subcontractPlan__description": "INDIVIDUAL SUBCONTRACT PLAN ",
#         "transactionInformation": "\n          ",
#         "transactionInformation__createdBy": "HHSSGOLAN",
#         "transactionInformation__createdDate": "2022-01-01 16:13:10",
#         "transactionInformation__lastModifiedBy": "HHSSGOLAN",
#         "transactionInformation__lastModifiedDate": "2022-01-01 16:13:11",
#         "transactionInformation__status": "F",
#         "transactionInformation__status__description": "FINAL",
#         "transactionInformation__approvedBy": "HHSSGOLAN",
#         "transactionInformation__approvedDate": "2022-01-01 16:13:11",
#         "transactionInformation__closedStatus": "N",
#         "genericTags": "\n          ",
#         "genericTags__genericStrings": "\n            ",
#         "genericTags__genericStrings__genericString02": "MZL5EGRMMXY5",
#         "vendor__vendorSiteDetails__vendorLocation__faxNo": "2022896801",
#         "genericTags__genericStrings__genericString01": "2021-10-18 00:00:00",
#         "genericTags__genericStrings__genericString06": "TO",
#         "IDV": "\n        ",
#         "IDV__version": "1.5",
#         "contractID": "\n          ",
#         "contractID__IDVID": "\n            ",
#         "contractID__IDVID__agencyID": "7523",
#         "contractID__IDVID__agencyID__name": "CENTERS FOR DISEASE CONTROL AND PREVENTION",
#         "contractID__IDVID__PIID": "75D30122D13001",
#         "contractID__IDVID__modNumber": "0",
#         "relevantContractDates__lastDateToOrder": "2023-02-28 00:00:00",
#         "dollarValues__totalEstimatedOrderValue": "208520000.00",
#         "contractMarketingData__websiteURL": "HTTP://WWW.SEQIRUS.COM",
#         "contractMarketingData__whoCanUse": "ONLY MY AGENCY",
#         "contractMarketingData__individualOrderLimit": "208520000",
#         "contractMarketingData__typeOfFeeForUseOfService": "NO",
#         "contractMarketingData__typeOfFeeForUseOfService__description": "NO FEE",
#         "contractData__typeOfIDC": "B",
#         "contractData__typeOfIDC__description": "INDEFINITE DELIVERY / INDEFINITE QUANTITY",
#         "contractData__multipleOrSingleAwardIDC": "S",
#         "contractData__multipleOrSingleAwardIDC__description": "SINGLE AWARD",
#         "contractData__programAcronym": "NA",
#         "contractData__listOfTreasuryAccounts": "\n            ",
#         "contractData__listOfTreasuryAccounts__treasuryAccount": "\n              ",
#         "contractData__listOfTreasuryAccounts__treasuryAccount__treasuryAccountSymbol": "\n                ",
#         "contractData__listOfTreasuryAccounts__treasuryAccount__treasuryAccountSymbol__agencyIdentifier": "75",
#         "contractData__listOfTreasuryAccounts__treasuryAccount__treasuryAccountSymbol__mainAccountCode": "0947",
#         "contractData__listOfTreasuryAccounts__treasuryAccount__treasuryAccountSymbol__subAccountCode": "000"
#     },
#     {
#         "title": "PURCHASE ORDER 75D30120P07393 (P00001) awarded to CENTER FOR ASBESTOS RELATED DISEASES, was modified for the amount of $0",
#         "contract_type": "AWARD",
#         "link__rel": "alternate",
#         "link__type": "text/html",
#         "link__href": "https://www.fpds.gov/ezsearch/search.do?s=FPDS&indexName=awardfull&templateName=1.5.3&q=75D30120P07393+7523+",
#         "modified": "2022-01-01 17:00:34",
#         "content": "\n      ",
#         "content__type": "application/xml",
#         "award": "\n        ",
#         "award__version": "1.5",
#         "awardID": "\n          ",
#         "awardID__awardContractID": "\n            ",
#         "awardID__awardContractID__agencyID": "7523",
#         "awardID__awardContractID__agencyID__name": "CENTERS FOR DISEASE CONTROL AND PREVENTION",
#         "awardID__awardContractID__PIID": "75D30120P07393",
#         "awardID__awardContractID__modNumber": "P00001",
#         "awardID__awardContractID__transactionNumber": "0",
#         "relevantContractDates": "\n          ",
#         "relevantContractDates__signedDate": "2022-01-01 00:00:00",
#         "relevantContractDates__effectiveDate": "2020-08-17 17:39:13",
#         "relevantContractDates__currentCompletionDate": "2022-08-31 00:00:00",
#         "relevantContractDates__ultimateCompletionDate": "2023-08-31 00:00:00",
#         "dollarValues": "\n          ",
#         "dollarValues__obligatedAmount": "0.00",
#         "dollarValues__baseAndExercisedOptionsValue": "0.00",
#         "dollarValues__baseAndAllOptionsValue": "0.00",
#         "totalDollarValues": "\n          ",
#         "totalDollarValues__totalObligatedAmount": "191860.00",
#         "totalDollarValues__totalBaseAndExercisedOptionsValue": "191860.00",
#         "totalDollarValues__totalBaseAndAllOptionsValue": "248610.00",
#         "purchaserInformation": "\n          ",
#         "purchaserInformation__contractingOfficeAgencyID": "7523",
#         "purchaserInformation__contractingOfficeAgencyID__name": "CENTERS FOR DISEASE CONTROL AND PREVENTION",
#         "purchaserInformation__contractingOfficeAgencyID__departmentID": "7500",
#         "purchaserInformation__contractingOfficeAgencyID__departmentName": "HEALTH AND HUMAN SERVICES, DEPARTMENT OF",
#         "purchaserInformation__contractingOfficeID": "75D301",
#         "purchaserInformation__contractingOfficeID__name": "CDC OFFICE OF ACQUISITION SERVICES",
#         "purchaserInformation__contractingOfficeID__country": "USA",
#         "purchaserInformation__fundingRequestingAgencyID": "7523",
#         "purchaserInformation__fundingRequestingAgencyID__name": "CENTERS FOR DISEASE CONTROL AND PREVENTION",
#         "purchaserInformation__fundingRequestingAgencyID__departmentID": "7500",
#         "purchaserInformation__fundingRequestingAgencyID__departmentName": "HEALTH AND HUMAN SERVICES, DEPARTMENT OF",
#         "purchaserInformation__fundingRequestingOfficeID": "75D301",
#         "purchaserInformation__fundingRequestingOfficeID__name": "CDC OFFICE OF ACQUISITION SERVICES",
#         "purchaserInformation__foreignFunding": "X",
#         "purchaserInformation__foreignFunding__description": "NOT APPLICABLE",
#         "contractMarketingData": "\n          ",
#         "contractMarketingData__feePaidForUseOfService": "0.00",
#         "contractData": "\n          ",
#         "contractData__contractActionType": "B",
#         "contractData__contractActionType__description": "PURCHASE ORDER",
#         "contractData__typeOfContractPricing": "J",
#         "contractData__typeOfContractPricing__description": "FIRM FIXED PRICE",
#         "contractData__reasonForModification": "M",
#         "contractData__reasonForModification__description": "OTHER ADMINISTRATIVE ACTION",
#         "contractData__nationalInterestActionCode": "NONE",
#         "contractData__nationalInterestActionCode__description": "NONE",
#         "contractData__costOrPricingData": "N",
#         "contractData__costOrPricingData__description": "No",
#         "contractData__solicitationID": "75D301-20-Q-71375",
#         "contractData__costAccountingStandardsClause": "N",
#         "contractData__costAccountingStandardsClause__description": "NO - CAS WAIVER APPROVED",
#         "contractData__descriptionOfContractRequirement": "DATABASE CREATION & DOUBLE DATA ENTRY SERVICES",
#         "contractData__inherentlyGovernmentalFunction": "OT        ",
#         "contractData__inherentlyGovernmentalFunction__description": "OTHER FUNCTIONS",
#         "contractData__GFE-GFP": "N",
#         "contractData__GFE-GFP__description": "Transaction does not use GFE/GFP",
#         "contractData__undefinitizedAction": "X",
#         "contractData__undefinitizedAction__description": "NO",
#         "contractData__consolidatedContract": "D",
#         "contractData__consolidatedContract__description": "NOT CONSOLIDATED",
#         "contractData__performanceBasedServiceContract": "N",
#         "contractData__performanceBasedServiceContract__description": "NO - SERVICE WHERE PBA IS NOT USED.",
#         "contractData__multiYearContract": "N",
#         "contractData__multiYearContract__description": "NO",
#         "contractData__contingencyHumanitarianPeacekeepingOperation": "X",
#         "contractData__contingencyHumanitarianPeacekeepingOperation__description": "NOT APPLICABLE",
#         "contractData__contractFinancing": "Z",
#         "contractData__contractFinancing__description": "NOT APPLICABLE",
#         "contractData__purchaseCardAsPaymentMethod": "N",
#         "contractData__purchaseCardAsPaymentMethod__description": "NO",
#         "contractData__numberOfActions": "1",
#         "legislativeMandates": "\n          ",
#         "legislativeMandates__ClingerCohenAct": "N",
#         "legislativeMandates__ClingerCohenAct__description": "NO",
#         "legislativeMandates__materialsSuppliesArticlesEquipment": "X",
#         "legislativeMandates__materialsSuppliesArticlesEquipment__description": "NOT APPLICABLE",
#         "legislativeMandates__laborStandards": "Y",
#         "legislativeMandates__laborStandards__description": "YES",
#         "legislativeMandates__constructionWageRateRequirements": "X",
#         "legislativeMandates__constructionWageRateRequirements__description": "NOT APPLICABLE",
#         "legislativeMandates__listOfAdditionalReportingValues": "\n            ",
#         "legislativeMandates__listOfAdditionalReportingValues__additionalReportingValue": "NONE",
#         "legislativeMandates__listOfAdditionalReportingValues__additionalReportingValue__description": "NONE OF THE ABOVE",
#         "legislativeMandates__interagencyContractingAuthority": "X",
#         "legislativeMandates__interagencyContractingAuthority__description": "NOT APPLICABLE",
#         "legislativeMandates__otherStatutoryAuthority": "FALSE",
#         "productOrServiceInformation": "\n          ",
#         "productOrServiceInformation__productOrServiceCode": "D303",
#         "productOrServiceInformation__productOrServiceCode__description": "IT AND TELECOM- DATA ENTRY",
#         "productOrServiceInformation__productOrServiceCode__productOrServiceType": "SERVICE",
#         "productOrServiceInformation__contractBundling": "H",
#         "productOrServiceInformation__contractBundling__description": "NOT BUNDLED",
#         "productOrServiceInformation__principalNAICSCode": "621111",
#         "productOrServiceInformation__principalNAICSCode__description": "OFFICES OF PHYSICIANS (EXCEPT MENTAL HEALTH SPECIALISTS)",
#         "productOrServiceInformation__recoveredMaterialClauses": "C",
#         "productOrServiceInformation__recoveredMaterialClauses__description": "NO CLAUSES INCLUDED AND NO SUSTAINABILITY INCLUDED",
#         "productOrServiceInformation__manufacturingOrganizationType": "A",
#         "productOrServiceInformation__manufacturingOrganizationType__description": "U.S. OWNED BUSINESS",
#         "productOrServiceInformation__useOfEPADesignatedProducts": "E",
#         "productOrServiceInformation__useOfEPADesignatedProducts__description": "NOT REQUIRED",
#         "productOrServiceInformation__countryOfOrigin": "USA",
#         "productOrServiceInformation__countryOfOrigin__name": "UNITED STATES",
#         "productOrServiceInformation__placeOfManufacture": "C",
#         "productOrServiceInformation__placeOfManufacture__description": "NOT A MANUFACTURED END PRODUCT",
#         "vendor": "\n          ",
#         "vendor__vendorHeader": "\n            ",
#         "vendor__vendorHeader__vendorName": "CENTER FOR ASBESTOS RELATED DISEASES",
#         "vendor__vendorHeader__vendorAlternateName": "MDA",
#         "vendor__vendorHeader__vendorLegalOrganizationName": "MUSCULAR DYSTROPHY ASSOCIATION, INC.",
#         "vendor__vendorSiteDetails": "\n            ",
#         "vendor__vendorSiteDetails__vendorSocioEconomicIndicators": "\n              ",
#         "vendor__vendorSiteDetails__vendorSocioEconomicIndicators__isAlaskanNativeOwnedCorporationOrFirm": "false",
#         "vendor__vendorSiteDetails__vendorSocioEconomicIndicators__isAmericanIndianOwned": "false",
#         "vendor__vendorSiteDetails__vendorSocioEconomicIndicators__isIndianTribe": "false",
#         "vendor__vendorSiteDetails__vendorSocioEconomicIndicators__isNativeHawaiianOwnedOrganizationOrFirm": "false",
#         "vendor__vendorSiteDetails__vendorSocioEconomicIndicators__isTriballyOwnedFirm": "false",
#         "vendor__vendorSiteDetails__vendorSocioEconomicIndicators__isSmallBusiness": "false",
#         "vendor__vendorSiteDetails__vendorSocioEconomicIndicators__isVeteranOwned": "false",
#         "vendor__vendorSiteDetails__vendorSocioEconomicIndicators__isServiceRelatedDisabledVeteranOwnedBusiness": "false",
#         "vendor__vendorSiteDetails__vendorSocioEconomicIndicators__isWomenOwned": "false",
#         "vendor__vendorSiteDetails__vendorSocioEconomicIndicators__minorityOwned": "\n                ",
#         "vendor__vendorSiteDetails__vendorSocioEconomicIndicators__minorityOwned__isMinorityOwned": "false",
#         "vendor__vendorSiteDetails__vendorSocioEconomicIndicators__minorityOwned__isSubContinentAsianAmericanOwnedBusiness": "false",
#         "vendor__vendorSiteDetails__vendorSocioEconomicIndicators__minorityOwned__isAsianPacificAmericanOwnedBusiness": "false",
#         "vendor__vendorSiteDetails__vendorSocioEconomicIndicators__minorityOwned__isBlackAmericanOwnedBusiness": "false",
#         "vendor__vendorSiteDetails__vendorSocioEconomicIndicators__minorityOwned__isHispanicAmericanOwnedBusiness": "false",
#         "vendor__vendorSiteDetails__vendorSocioEconomicIndicators__minorityOwned__isNativeAmericanOwnedBusiness": "false",
#         "vendor__vendorSiteDetails__vendorSocioEconomicIndicators__minorityOwned__isOtherMinorityOwned": "false",
#         "vendor__vendorSiteDetails__vendorSocioEconomicIndicators__isVerySmallBusiness": "false",
#         "vendor__vendorSiteDetails__vendorSocioEconomicIndicators__isWomenOwnedSmallBusiness": "false",
#         "vendor__vendorSiteDetails__vendorSocioEconomicIndicators__isEconomicallyDisadvantagedWomenOwnedSmallBusiness": "false",
#         "vendor__vendorSiteDetails__vendorSocioEconomicIndicators__isJointVentureWomenOwnedSmallBusiness": "false",
#         "vendor__vendorSiteDetails__vendorSocioEconomicIndicators__isJointVentureEconomicallyDisadvantagedWomenOwnedSmallBusiness": "false",
#         "vendor__vendorSiteDetails__vendorBusinessTypes": "\n              ",
#         "vendor__vendorSiteDetails__vendorBusinessTypes__isCommunityDevelopedCorporationOwnedFirm": "false",
#         "vendor__vendorSiteDetails__vendorBusinessTypes__isLaborSurplusAreaFirm": "false",
#         "vendor__vendorSiteDetails__vendorBusinessTypes__federalGovernment": "\n                ",
#         "vendor__vendorSiteDetails__vendorBusinessTypes__federalGovernment__isFederalGovernment": "false",
#         "vendor__vendorSiteDetails__vendorBusinessTypes__federalGovernment__isFederallyFundedResearchAndDevelopmentCorp": "false",
#         "vendor__vendorSiteDetails__vendorBusinessTypes__federalGovernment__isFederalGovernmentAgency": "false",
#         "vendor__vendorSiteDetails__vendorBusinessTypes__isStateGovernment": "false",
#         "vendor__vendorSiteDetails__vendorBusinessTypes__localGovernment": "\n                ",
#         "vendor__vendorSiteDetails__vendorBusinessTypes__localGovernment__isLocalGovernment": "false",
#         "vendor__vendorSiteDetails__vendorBusinessTypes__localGovernment__isCityLocalGovernment": "false",
#         "vendor__vendorSiteDetails__vendorBusinessTypes__localGovernment__isCountyLocalGovernment": "false",
#         "vendor__vendorSiteDetails__vendorBusinessTypes__localGovernment__isInterMunicipalLocalGovernment": "false",
#         "vendor__vendorSiteDetails__vendorBusinessTypes__localGovernment__isLocalGovernmentOwned": "false",
#         "vendor__vendorSiteDetails__vendorBusinessTypes__localGovernment__isMunicipalityLocalGovernment": "false",
# ...
#         "vendor__vendorSiteDetails__vendorBusinessTypes__isLaborSurplusAreaFirm": "false",
#         "vendor__vendorSiteDetails__vendorBusinessTypes__federalGovernment": "\n                ",
#         "vendor__vendorSiteDetails__vendorBusinessTypes__federalGovernment__isFederalGovernment": "false",
#         "vendor__vendorSiteDetails__vendorBusinessTypes__federalGovernment__isFederallyFundedResearchAndDevelopmentCorp": "false",
#         "vendor__vendorSiteDetails__vendorBusinessTypes__federalGovernment__isFederalGovernmentAgency": "false",
#         "vendor__vendorSiteDetails__vendorBusinessTypes__isStateGovernment": "false",
#         "vendor__vendorSiteDetails__vendorBusinessTypes__localGovernment": "\n                ",
#         "vendor__vendorSiteDetails__vendorBusinessTypes__localGovernment__isLocalGovernment": "false",
#         "vendor__vendorSiteDetails__vendorBusinessTypes__localGovernment__isCityLocalGovernment": "false",
#         "vendor__vendorSiteDetails__vendorBusinessTypes__localGovernment__isCountyLocalGovernment": "false",
#         "vendor__vendorSiteDetails__vendorBusinessTypes__localGovernment__isInterMunicipalLocalGovernment": "false",
#         "vendor__vendorSiteDetails__vendorBusinessTypes__localGovernment__isLocalGovernmentOwned": "false",
#         "vendor__vendorSiteDetails__vendorBusinessTypes__localGovernment__isMunicipalityLocalGovernment": "false",
#         "vendor__vendorSiteDetails__vendorBusinessTypes__localGovernment__isSchoolDistrictLocalGovernment": "false",
#         "vendor__vendorSiteDetails__vendorBusinessTypes__localGovernment__isTownshipLocalGovernment": "false",
#         "vendor__vendorSiteDetails__vendorBusinessTypes__isTribalGovernment": "false",
#         "vendor__vendorSiteDetails__vendorBusinessTypes__isForeignGovernment": "false",
#         "vendor__vendorSiteDetails__vendorBusinessTypes__businessOrOrganizationType": "\n                ",
#         "vendor__vendorSiteDetails__vendorBusinessTypes__businessOrOrganizationType__isCorporateEntityNotTaxExempt": "false",
#         "vendor__vendorSiteDetails__vendorBusinessTypes__businessOrOrganizationType__isCorporateEntityTaxExempt": "true",
#         "vendor__vendorSiteDetails__vendorBusinessTypes__businessOrOrganizationType__isPartnershipOrLimitedLiabilityPartnership": "false",
#         "vendor__vendorSiteDetails__vendorBusinessTypes__businessOrOrganizationType__isSolePropreitorship": "false",
#         "vendor__vendorSiteDetails__vendorBusinessTypes__businessOrOrganizationType__isSmallAgriculturalCooperative": "false",
#         "vendor__vendorSiteDetails__vendorBusinessTypes__businessOrOrganizationType__isInternationalOrganization": "false",
#         "vendor__vendorSiteDetails__vendorBusinessTypes__businessOrOrganizationType__isUSGovernmentEntity": "false",
#         "vendor__vendorSiteDetails__vendorLineOfBusiness": "\n              ",
#         "vendor__vendorSiteDetails__vendorLineOfBusiness__isCommunityDevelopmentCorporation": "false",
#         "vendor__vendorSiteDetails__vendorLineOfBusiness__isDomesticShelter": "false",
#         "vendor__vendorSiteDetails__vendorLineOfBusiness__isEducationalInstitution": "false",
#         "vendor__vendorSiteDetails__vendorLineOfBusiness__isFoundation": "false",
#         "vendor__vendorSiteDetails__vendorLineOfBusiness__isHospital": "false",
#         "vendor__vendorSiteDetails__vendorLineOfBusiness__isManufacturerOfGoods": "false",
#         "vendor__vendorSiteDetails__vendorLineOfBusiness__isVeterinaryHospital": "false",
#         "vendor__vendorSiteDetails__vendorLineOfBusiness__isHispanicServicingInstitution": "false",
#         "vendor__vendorSiteDetails__vendorRelationshipWithFederalGovernment": "\n              ",
#         "vendor__vendorSiteDetails__vendorRelationshipWithFederalGovernment__receivesContracts": "false",
#         "vendor__vendorSiteDetails__vendorRelationshipWithFederalGovernment__receivesGrants": "false",
#         "vendor__vendorSiteDetails__vendorRelationshipWithFederalGovernment__receivesContractsAndGrants": "true",
#         "vendor__vendorSiteDetails__typeOfGovernmentEntity": "\n              ",
#         "vendor__vendorSiteDetails__typeOfGovernmentEntity__isAirportAuthority": "false",
#         "vendor__vendorSiteDetails__typeOfGovernmentEntity__isCouncilOfGovernments": "false",
#         "vendor__vendorSiteDetails__typeOfGovernmentEntity__isHousingAuthoritiesPublicOrTribal": "false",
#         "vendor__vendorSiteDetails__typeOfGovernmentEntity__isInterstateEntity": "false",
#         "vendor__vendorSiteDetails__typeOfGovernmentEntity__isPlanningCommission": "false",
#         "vendor__vendorSiteDetails__typeOfGovernmentEntity__isPortAuthority": "false",
#         "vendor__vendorSiteDetails__typeOfGovernmentEntity__isTransitAuthority": "false",
#         "vendor__vendorSiteDetails__vendorOrganizationFactors": "\n              ",
#         "vendor__vendorSiteDetails__vendorOrganizationFactors__isSubchapterSCorporation": "false",
#         "vendor__vendorSiteDetails__vendorOrganizationFactors__isLimitedLiabilityCorporation": "false",
#         "vendor__vendorSiteDetails__vendorOrganizationFactors__isForeignOwnedAndLocated": "false",
#         "vendor__vendorSiteDetails__vendorOrganizationFactors__profitStructure": "\n                ",
#         "vendor__vendorSiteDetails__vendorOrganizationFactors__profitStructure__isForProfitOrganization": "false",
#         "vendor__vendorSiteDetails__vendorOrganizationFactors__profitStructure__isNonprofitOrganization": "true",
#         "vendor__vendorSiteDetails__vendorOrganizationFactors__profitStructure__isOtherNotForProfitOrganization": "false",
#         "vendor__vendorSiteDetails__vendorOrganizationFactors__isShelteredWorkshop": "false",
#         "vendor__vendorSiteDetails__vendorOrganizationFactors__stateOfIncorporation": "DE",
#         "vendor__vendorSiteDetails__vendorOrganizationFactors__stateOfIncorporation__name": "DELAWARE",
#         "vendor__vendorSiteDetails__vendorOrganizationFactors__countryOfIncorporation": "USA",
#         "vendor__vendorSiteDetails__vendorOrganizationFactors__countryOfIncorporation__name": "UNITED STATES",
#         "vendor__vendorSiteDetails__vendorOrganizationFactors__organizationalType": "CORPORATE TAX EXEMPT",
#         "vendor__vendorSiteDetails__typeOfEducationalEntity": "\n              ",
#         "vendor__vendorSiteDetails__typeOfEducationalEntity__is1862LandGrantCollege": "false",
#         "vendor__vendorSiteDetails__typeOfEducationalEntity__is1890LandGrantCollege": "false",
#         "vendor__vendorSiteDetails__typeOfEducationalEntity__is1994LandGrantCollege": "false",
#         "vendor__vendorSiteDetails__typeOfEducationalEntity__isHistoricallyBlackCollegeOrUniversity": "false",
#         "vendor__vendorSiteDetails__typeOfEducationalEntity__isMinorityInstitution": "false",
#         "vendor__vendorSiteDetails__typeOfEducationalEntity__isPrivateUniversityOrCollege": "false",
#         "vendor__vendorSiteDetails__typeOfEducationalEntity__isSchoolOfForestry": "false",
#         "vendor__vendorSiteDetails__typeOfEducationalEntity__isStateControlledInstitutionofHigherLearning": "false",
#         "vendor__vendorSiteDetails__typeOfEducationalEntity__isTribalCollege": "false",
#         "vendor__vendorSiteDetails__typeOfEducationalEntity__isVeterinaryCollege": "false",
#         "vendor__vendorSiteDetails__typeOfEducationalEntity__isAlaskanNativeServicingInstitution": "false",
#         "vendor__vendorSiteDetails__typeOfEducationalEntity__isNativeHawaiianServicingInstitution": "false",
#         "vendor__vendorSiteDetails__vendorCertifications": "\n              ",
#         "vendor__vendorSiteDetails__vendorCertifications__isDOTCertifiedDisadvantagedBusinessEnterprise": "false",
#         "vendor__vendorSiteDetails__vendorCertifications__isSelfCertifiedSmallDisadvantagedBusiness": "false",
#         "vendor__vendorSiteDetails__vendorCertifications__isSBACertifiedSmallDisadvantagedBusiness": "false",
#         "vendor__vendorSiteDetails__vendorCertifications__isSBACertified8AProgramParticipant": "false",
#         "vendor__vendorSiteDetails__vendorCertifications__isSelfCertifiedHUBZoneJointVenture": "false",
#         "vendor__vendorSiteDetails__vendorCertifications__isSBACertifiedHUBZone": "false",
#         "vendor__vendorSiteDetails__vendorCertifications__isSBACertified8AJointVenture": "false",
#         "vendor__vendorSiteDetails__vendorLocation": "\n              ",
#         "vendor__vendorSiteDetails__vendorLocation__streetAddress": "1275 K ST NW STE 250",
#         "vendor__vendorSiteDetails__vendorLocation__city": "WASHINGTON",
#         "vendor__vendorSiteDetails__vendorLocation__state": "DC",
#         "vendor__vendorSiteDetails__vendorLocation__state__name": "DISTRICT OF COLUMBIA",
#         "vendor__vendorSiteDetails__vendorLocation__ZIPCode": "200056823",
#         "vendor__vendorSiteDetails__vendorLocation__ZIPCode__city": "WASHINGTON",
#         "vendor__vendorSiteDetails__vendorLocation__countryCode": "USA",
#         "vendor__vendorSiteDetails__vendorLocation__countryCode__name": "UNITED STATES",
#         "vendor__vendorSiteDetails__vendorLocation__phoneNo": "2024648651",
#         "vendor__vendorSiteDetails__vendorLocation__congressionalDistrictCode": "08",
#         "vendor__vendorSiteDetails__vendorLocation__entityDataSource": "D&B",
#         "vendor__vendorSiteDetails__vendorAlternateSiteCode": "20005",
#         "vendor__vendorSiteDetails__entityIdentifiers": "\n              ",
#         "vendor__vendorSiteDetails__entityIdentifiers__vendorUEIInformation": "\n                ",
#         "vendor__vendorSiteDetails__entityIdentifiers__vendorUEIInformation__UEI": "KMHZW7EM1997",
#         "vendor__vendorSiteDetails__entityIdentifiers__vendorUEIInformation__UEILegalBusinessName": "AMYOTROPHIC LATERAL SCLEROSIS ASSOCIATION, THE",
#         "vendor__vendorSiteDetails__entityIdentifiers__vendorUEIInformation__ultimateParentUEI": "KMHZW7EM1997",
#         "vendor__vendorSiteDetails__entityIdentifiers__vendorUEIInformation__ultimateParentUEIName": "THE AMYOTROPHIC LATERAL SCLEROSIS ASSOCIATION",
#         "vendor__vendorSiteDetails__entityIdentifiers__cageCode": "4SX84",
#         "vendor__vendorSiteDetails__ccrRegistrationDetails": "\n              ",
#         "vendor__vendorSiteDetails__ccrRegistrationDetails__registrationDate": "2007-06-26 00:00:00",
#         "vendor__vendorSiteDetails__ccrRegistrationDetails__renewalDate": "2017-07-27 00:00:00",
#         "vendor__contractingOfficerBusinessSizeDetermination": "O",
#         "vendor__contractingOfficerBusinessSizeDetermination__description": "OTHER THAN SMALL BUSINESS",
#         "placeOfPerformance": "\n          ",
#         "placeOfPerformance__principalPlaceOfPerformance": "\n            ",
#         "placeOfPerformance__principalPlaceOfPerformance__stateCode": "DC",
#         "placeOfPerformance__principalPlaceOfPerformance__stateCode__name": "DISTRICT OF COLUMBIA",
#         "placeOfPerformance__principalPlaceOfPerformance__countryCode": "USA",
#         "placeOfPerformance__principalPlaceOfPerformance__countryCode__name": "UNITED STATES",
#         "placeOfPerformance__placeOfPerformanceZIPCode": "200056823",
#         "placeOfPerformance__placeOfPerformanceZIPCode__county": "DISTRICT OF COLUMBIA",
#         "placeOfPerformance__placeOfPerformanceZIPCode__city": "WASHINGTON",
#         "placeOfPerformance__placeOfPerformanceCongressionalDistrict": "98",
#         "competition": "\n          ",
#         "competition__extentCompeted": "C",
#         "competition__extentCompeted__description": "NOT COMPETED",
#         "competition__solicitationProcedures": "SSS",
#         "competition__solicitationProcedures__description": "ONLY ONE SOURCE",
#         "competition__typeOfSetAside": "NONE",
#         "competition__typeOfSetAside__description": "NO SET ASIDE USED.",
#         "competition__typeOfSetAsideSource": "F",
#         "competition__typeOfSetAsideSource__description": "This Action",
#         "competition__evaluatedPreference": "NONE",
#         "competition__evaluatedPreference__description": "NO PREFERENCE USED",
#         "competition__reasonNotCompeted": "ONE",
#         "competition__reasonNotCompeted__description": "ONLY ONE SOURCE-OTHER (FAR 6.302-1 OTHER)",
#         "competition__numberOfOffersReceived": "1",
#         "competition__numberOfOffersSource": "F",
#         "competition__numberOfOffersSource__description": "This Action",
#         "competition__commercialItemAcquisitionProcedures": "D",
#         "competition__commercialItemAcquisitionProcedures__description": "COMMERCIAL ITEM PROCEDURES NOT USED",
#         "competition__commercialItemTestProgram": "N",
#         "competition__commercialItemTestProgram__description": "NO",
#         "competition__A76Action": "N",
#         "competition__A76Action__description": "NO",
#         "competition__fedBizOpps": "Y",
#         "competition__fedBizOpps__description": "YES",
#         "competition__localAreaSetAside": "N",
#         "competition__localAreaSetAside__description": "NO",
#         "competition__priceEvaluationPercentDifference": "0.00",
#         "preferencePrograms": "\n          ",
#         "preferencePrograms__subcontractPlan": "A",
#         "preferencePrograms__subcontractPlan__description": "PLAN NOT INCLUDED - NO SUBCONTRACTING POSSIBILITIES ",
#         "transactionInformation": "\n          ",
#         "transactionInformation__createdBy": "HHSSGOLAN",
#         "transactionInformation__createdDate": "2022-01-01 15:24:27",
#         "transactionInformation__lastModifiedBy": "HHSSGOLAN",
#         "transactionInformation__lastModifiedDate": "2022-01-01 15:24:28",
#         "transactionInformation__status": "F",
#         "transactionInformation__status__description": "FINAL",
#         "transactionInformation__approvedBy": "HHSSGOLAN",
#         "transactionInformation__approvedDate": "2022-01-01 15:24:28",
#         "transactionInformation__closedStatus": "N",
#         "genericTags": "\n          ",
#         "genericTags__genericStrings": "\n            ",
#         "genericTags__genericStrings__genericString02": "KMHZW7EM1997",
#         "vendor__vendorSiteDetails__vendorLocation__faxNo": "2022896801",
#         "genericTags__genericStrings__genericString01": "2021-10-18 00:00:00",
#         "genericTags__genericStrings__genericString06": "TO",
#         "IDV": "\n        ",
#         "IDV__version": "1.5",
#         "contractID": "\n          ",
#         "contractID__IDVID": "\n            ",
#         "contractID__IDVID__agencyID": "7523",
#         "contractID__IDVID__agencyID__name": "CENTERS FOR DISEASE CONTROL AND PREVENTION",
#         "contractID__IDVID__PIID": "75D30122D13001",
#         "contractID__IDVID__modNumber": "0",
#         "relevantContractDates__lastDateToOrder": "2023-02-28 00:00:00",
#         "dollarValues__totalEstimatedOrderValue": "208520000.00",
#         "contractMarketingData__websiteURL": "HTTP://WWW.SEQIRUS.COM",
#         "contractMarketingData__whoCanUse": "ONLY MY AGENCY",
#         "contractMarketingData__individualOrderLimit": "208520000",
#         "contractMarketingData__typeOfFeeForUseOfService": "NO",
#         "contractMarketingData__typeOfFeeForUseOfService__description": "NO FEE",
#         "contractData__typeOfIDC": "B",
#         "contractData__typeOfIDC__description": "INDEFINITE DELIVERY / INDEFINITE QUANTITY",
#         "contractData__multipleOrSingleAwardIDC": "S",
#         "contractData__multipleOrSingleAwardIDC__description": "SINGLE AWARD",
#         "contractData__programAcronym": "NA",
#         "contractData__listOfTreasuryAccounts": "\n            ",
#         "contractData__listOfTreasuryAccounts__treasuryAccount": "\n              ",
#         "contractData__listOfTreasuryAccounts__treasuryAccount__treasuryAccountSymbol": "\n                ",
#         "contractData__listOfTreasuryAccounts__treasuryAccount__treasuryAccountSymbol__agencyIdentifier": "75",
#         "contractData__listOfTreasuryAccounts__treasuryAccount__treasuryAccountSymbol__mainAccountCode": "0947",
#         "contractData__listOfTreasuryAccounts__treasuryAccount__treasuryAccountSymbol__subAccountCode": "000"
#     }
# ]
